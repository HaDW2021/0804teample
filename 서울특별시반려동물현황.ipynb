# %%
import pandas as pd

# 탭으로 분리된(tsv) .txt 텍스트파일 불러오기
# data = pd.read_csv('파일경로', sep = "\t", engine='python', encoding = "인코딩방식")
data = pd.read_csv('dataset/report.txt', sep = "\t", engine='python')
data
# [출처] Pandas로 txt 파일 불러오기|작성자 데이터공방
# Out:
#        기간  대분류      분류 반려동물 여부 반려동물 여부.1 반려동물 취득경로 반려동물 취득경로.1 반려동물 취득경로.2  \
# 0      기간  대분류      분류      있다        없다    동물판매업소        유상입양        무상입양
# 1    2014  서울시     서울시    19.4      80.6      34.6        18.9        39.4
# 2    2014   성별      남자    18.8      81.2        35          18        39.9
# 3    2014   성별      여자    22.5      77.5      32.9        23.1        37.2
# 4    2014  연령별  20대 이하    21.5      78.5        42        20.4        33.1
# ..    ...  ...     ...     ...       ...       ...         ...         ...
# 416  2020  관악구     관악구    16.6      83.4      22.9        20.2        36.4
# 417  2020  서초구     서초구    21.6      78.4      29.9        21.8        32.1
# 418  2020  강남구     강남구    21.4      78.6        28        19.8        29.1
# 419  2020  송파구     송파구    21.6      78.4      29.9        10.2        40.8
# 420  2020  강동구     강동구    19.2      80.8      13.1        19.7        38.8
#
#     반려동물 취득경로.3 반려동물 취득경로.4       반려동물 취득경로.5 반려동물 취득경로.6
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
data.to_csv('dataset/seoulanswer', index = False)
